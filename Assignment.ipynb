# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
#  Read the dataset

# %%
iris=pd.read_excel(r"C:\Users\aksmk\OneDrive\Desktop\DSA\Assignments\1\iris.xls", sheet_name='Sheet1')

# %% [markdown]
# Display the columns

# %%
iris.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# Calculate mean of each column

# %%
iris[['SL','SW','PL','PW']].mean()
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
#  Check for null values

# %%
iris.isnull().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# Scatter Plot

# %%
plt.xlabel('PL')
plt.ylabel('PW')
plt.scatter(iris['PL'],iris['PW'])

# %% [markdown]
# Box Plot

# %%
plt.boxplot(iris['PL'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1339d07b210>,
#   <matplotlib.lines.Line2D at 0x1339d106090>],
#  'caps': [<matplotlib.lines.Line2D at 0x1339d106b90>,
#   <matplotlib.lines.Line2D at 0x1339d107710>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1339d062650>],
#  'medians': [<matplotlib.lines.Line2D at 0x1339d10c350>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1339d0671d0>],
#  'means': []}

# %% [markdown]
# Pair Plot

# %%
sns.pairplot(iris)
# Out:
# C:\Users\aksmk\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Histogram

# %%
plt.hist(iris['PL'])
# Out:
# (array([37., 13.,  0.,  3.,  8., 26., 29., 18., 11.,  5.]),
#  array([1.  , 1.59, 2.18, 2.77, 3.36, 3.95, 4.54, 5.13, 5.72, 6.31, 6.9 ]),
#  <BarContainer object of 10 artists>)
